# %% [markdown]
# <a href="https://colab.research.google.com/github/babalukadam/pract-demo/blob/main/list_and_tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello practiceing about list and tuple ")
# Out:
# hello practiceing about list and tuple

# %%
user=["rakesh","ganesh","mukesh","dinesh"]
user[1:1]=["jignesh","hitesh","shailesh"]
user
# Out:
# ['rakesh', 'jignesh', 'hitesh', 'shailesh', 'ganesh', 'mukesh', 'dinesh']

# %%
user[1:3]=["hitesh","jignesh"]
print(user)
# Out:
# ['rakesh', 'hitesh', 'jignesh', 'shailesh', 'ganesh', 'mukesh', 'dinesh']

# %%
del user[0]

# %%
user
# Out:
# ['hitesh', 'jignesh', 'shailesh', 'ganesh', 'mukesh', 'dinesh']

# %%
user[0:0]=["rakesh"]

# %%
user.append("Zoresh")

# %%
user.sort()
user
# Out:
# ['Zoresh',
#  'dinesh',
#  'ganesh',
#  'hitesh',
#  'jignesh',
#  'mukesh',
#  'rakesh',
#  'shailesh']

# %%
user.pop()
# Out:
# 'zoresh'

# %%
user.sort(key=str.lower)
user
# Out:
# ['dinesh',
#  'ganesh',
#  'hitesh',
#  'jignesh',
#  'mukesh',
#  'rakesh',
#  'shailesh',
#  'Zoresh']

# %%
nums=[1,6,4,7,44,8,74,8,754,8,98,7,43,3,678,33]
# here we sorted the lsit for olnly for the result not changing the exact list
# after sorting if we want to reverse the result list then we use reverse and make that true
print(sorted(nums,reverse=False))
# and also if we want uique values for that then we use this way
# actually we used set fuction for that beecz set is unique values

print(sorted(set(nums)))
print(nums)
# Out:
# [1, 3, 4, 6, 7, 7, 8, 8, 8, 33, 43, 44, 74, 98, 678, 754]
# [1, 3, 4, 6, 7, 8, 33, 43, 44, 74, 98, 678, 754]
# [1, 6, 4, 7, 44, 8, 74, 8, 754, 8, 98, 7, 43, 3, 678, 33]

# %%
print(user.index("mukesh"))

# %%
# TUPLES
atuple=("mukesh",34,True,"disnesh",3444,543)
type(atuple)
(*a,b,c)=atuple
# here we are unpacking the tuple so if we just take a as verialble it will return only value but if we add * then it will return all the values

print(a)
print(b)
print(c)
# Out:
# ['mukesh', 34, True, 'disnesh']
# 3444
# 543

# %% [markdown]
# # New Section
# here onwords we have discuss about litle bit str dataype

# %%
strs=" hello dinesh how are you "

# %%
# here we some of inbuild method for manipulation and filter the string output we use one by one and cheak the out put
strs.replace("dinesh","mukesh")
# here that value get change only for one time

strs
# if we want change permant then
strs=strs.replace("dinesh","mukesh")
strs
# now this will change permonantly
# Out:
# ' hello mukesh how are you '

# %%
# this title fuction make ec=vry first char is capatial

strs.title()
a=strs
a=a.upper() #to make entirre string capatal
a=a.lower()# to make entire string small case
aa="                       "+a+"                                                    "
len(aa)
len(aa.strip())
print(strs)
print(aa.strip()) #remove entire spaces from str right and left side
print(len(aa.rstrip())) #remove spaces from only right side
print(len(aa.lstrip())) #removing from left side
# Out:
#  hello mukesh how are you
# hello mukesh how are you
# 24

# %%
# not used anywhere but for just to know we have some fillowing method
r="menu"
r=r.upper()
print(r.center(20,"-"))
print("coffie".ljust(16,".")+"2$".rjust(4))
print("chai".ljust(16,".")+"1$".rjust(4))
print("dosa".ljust(16,".")+"5$".rjust(4))
print("poha".ljust(16,".")+"3$".rjust(4))
print("Thank you".center(20,"-"))
# here we used some of following methods
# 1.ljust means to add into output (value and occurance ) same for right but only side change
# used centr for as u seen in result
# Out:
# --------MENU--------
# coffie..........  2$
# chai............  1$
# dosa............  5$
# poha............  3$
# -----Thank you------

# %%
a="rakesh"
m=a.startswith("ra")
z=a.endswith("k")
print(m)
print(z)
# m
# Out:
# True
# False

# %%
a=-6.77123456

print(abs(a))# this will help to make negative value to positive
print(a)
print(round(a))#round off and take nearest value

print(round(a,1)) #this will take nearest value of decimal
# Out:
# 6.77123456
# -6.77123456
# -7
# -6.8

# %%
import math
a=math.pi
a=7
a=math.sqrt(a)
print(a)
# print(math.ceil(a))
a=math.floor(a)
#
print(a)
# Out:
# 2.6457513110645907
# 2

# %% [markdown]
# dictionary and sets # New Section

# %%
random={
    "name":"rakesh",
    "age":32,
    "job":"watchman",
    "nightshift":True
}

# %%
random1={
   "rakesh": {
    "age":32,
    "job":"watchman",
    "nightshift":True},
    "mukesh": {
        "age":32,
        "job":"watchman",
        "nightshift":True
     }


}
random.items()
# Out:
# dict_items([('name', 'rakesh'), ('age', 32), ('job', 'watchman'), ('nightshift', True)])

# %%
random.keys()
random.values()
# Out:
# dict_values(['rakesh', 32, 'watchman', True])

# %%
print(type(random))
print(len(random))
print(random)
# Out:
# <class 'dict'>
# 4
# {'name': 'rakesh', 'age': 32, 'job': 'watchman', 'nightshift': True}

# %%
random["name"]="dinesh"#overwrite value of name

# %%
random.update({"city":"landon"}) #add more kwey value pair inside dict
random
# Out:
# {'name': 'dinesh',
#  'age': 32,
#  'job': 'watchman',
#  'nightshift': True,
#  'city': 'landon'}

# %%
random.pop("city")
random
# Out:
# {'name': 'dinesh', 'age': 32, 'job': 'watchman', 'nightshift': True}

# %%
random.popitem()
# Out:
# ('city', 'landon')

# %%
random
# Out:
# {'name': 'dinesh', 'age': 32, 'job': 'watchman', 'nightshift': True}

# %% [markdown]
# set# New Section

# %%
a={1,2,4,6,7,4,6,7,8,5,6,8,8,5,79,9,5,3,4,7,8,3}
print(a)#becoz a is a set
a.add(12)
a
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 79}
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 12, 79}

# %%
# a.append(0) we are not able to use append method becoz for set add method is there
morenums={4,6,3,7,4,6,7,8,5}
a={1,2,6,8,8,5,79,9,5,7,8}
print(a)
print(morenums)
a.update(morenums)
print(a)
# Out:
# {1, 2, 5, 6, 7, 8, 9, 79}
# {3, 4, 5, 6, 7, 8}
# {1, 2, 5, 6, 7, 8, 9, 79}

# %%
a.union(morenums)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 79}

# %%
a.update(morenums)
a
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 79}
